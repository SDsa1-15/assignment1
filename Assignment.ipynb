# %%
import pandas as pd

# %%
spotify_df=pd.read_csv('https://raw.githubusercontent.com/Somyadhariwal/Soul/main/spotify_dataset%20(1).csv?token=AVEX6VK53DSFXWEBEBTJJ5LBFTWFC')
spotify_df.head(10)
# Out:
#    Index  Highest Charting Position  ...  Valence  Chord
# 0      1                          1  ...    0.589      B
# 1      2                          2  ...    0.478  C#/Db
# 2      3                          1  ...    0.688      A
# 3      4                          3  ...    0.591      B
# 4      5                          5  ...    0.894  D#/Eb
# 5      6                          1  ...    0.758  G#/Ab
# 6      7                          3  ...    0.742  G#/Ab
# 7      8                          2  ...    0.342  D#/Eb
# 8      9                          3  ...     0.44  C#/Db
# 9     10                          8  ...    0.958  C#/Db
#
# [10 rows x 23 columns]

# %%
pd.set_option('display.max_columns', 7)

# %%
spotify_df.head(10)
# Out:
#    Index  Highest Charting Position  Number of Times Charted  ...  \
# 0      1                          1                        8  ...
# 1      2                          2                        3  ...
# 2      3                          1                       11  ...
# 3      4                          3                        5  ...
# 4      5                          5                        1  ...
# 5      6                          1                       18  ...
# 6      7                          3                       16  ...
# 7      8                          2                       10  ...
# 8      9                          3                        8  ...
# 9     10                          8                       10  ...
#
#   Duration (ms) Valence  Chord
# 0        211560   0.589      B
# 1        141806   0.478  C#/Db
# 2        178147   0.688      A
# 3        231041   0.591      B
# 4        212000   0.894  D#/Eb
# 5        137876   0.758  G#/Ab
# ...

# %%
list(spotify_df.columns)
# Out:
# ['Index',
#  'Highest Charting Position',
#  'Number of Times Charted',
#  'Week of Highest Charting',
#  'Song Name',
#  'Streams',
#  'Artist',
#  'Artist Followers',
#  'Song ID',
#  'Genre',
#  'Release Date',
#  'Weeks Charted',
#  'Popularity',
#  'Danceability',
#  'Energy',
#  'Loudness',
#  'Speechiness',
#  'Acousticness',
#  'Liveness',
#  'Tempo',
#  'Duration (ms)',
#  'Valence',
#  'Chord']

# %%
spotify_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1556 entries, 0 to 1555
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Index                      1556 non-null   int64
#  1   Highest Charting Position  1556 non-null   int64
#  2   Number of Times Charted    1556 non-null   int64
#  3   Week of Highest Charting   1556 non-null   object
#  4   Song Name                  1556 non-null   object
#  5   Streams                    1556 non-null   object
#  6   Artist                     1556 non-null   object
#  7   Artist Followers           1556 non-null   object
#  8   Song ID                    1556 non-null   object
#  9   Genre                      1556 non-null   object
#  10  Release Date               1556 non-null   object
#  11  Weeks Charted              1556 non-null   object
#  12  Popularity                 1556 non-null   object
# ...

# %%
spotify_df[0:20]
# Out:
#     Index  Highest Charting Position  Number of Times Charted  ...  \
# 0       1                          1                        8  ...
# 1       2                          2                        3  ...
# 2       3                          1                       11  ...
# 3       4                          3                        5  ...
# 4       5                          5                        1  ...
# 5       6                          1                       18  ...
# 6       7                          3                       16  ...
# 7       8                          2                       10  ...
# 8       9                          3                        8  ...
# 9      10                          8                       10  ...
# 10     11                          4                       43  ...
# 11     12                          9                        9  ...
# 12     13                          5                        3  ...
# ...

# %%
spotify_df[-5:]
# Out:
#       Index  Highest Charting Position  Number of Times Charted  ... Valence  \
# 1551   1552                        195                        1  ...   0.608
# 1552   1553                        196                        1  ...   0.714
# 1553   1554                        197                        1  ...   0.394
# 1554   1555                        198                        1  ...   0.881
# 1555   1556                        199                        1  ...   0.422
#
#      Chord             Famous
# 1551     A  271676754,630,675
# 1552     B  150191094,623,030
# 1553     D  226987474,620,876
# 1554     F    2086304,607,385
# 1555     G  422276144,595,450
#
# [5 rows x 24 columns]

# %%
spotify_df.dtypes
# Out:
# Index                         int64
# Highest Charting Position     int64
# Number of Times Charted       int64
# Week of Highest Charting     object
# Song Name                    object
# Streams                      object
# Artist                       object
# Artist Followers             object
# Song ID                      object
# Genre                        object
# Release Date                 object
# Weeks Charted                object
# Popularity                   object
# Danceability                 object
# Energy                       object
# Loudness                     object
# Speechiness                  object
# Acousticness                 object
# Liveness                     object
# Tempo                        object
# Duration (ms)                object
# Valence                      object
# Chord                        object
# Famous                       object
# dtype: object

# %%
spotify_df['Streams'] = pd.to_numeric(spotify_df['Streams'], errors='coerce')
spotify_df['Popularity'] = pd.to_numeric(spotify_df['Popularity'], errors='coerce')
spotify_df['Danceability'] = pd.to_numeric(spotify_df['Danceability'], errors='coerce')
spotify_df['Energy'] = pd.to_numeric(spotify_df['Energy'], errors='coerce')
spotify_df['Loudness'] = pd.to_numeric(spotify_df['Loudness'], errors='coerce')
spotify_df['Tempo'] = pd.to_numeric(spotify_df['Tempo'], errors='coerce')
spotify_df['Liveness'] = pd.to_numeric(spotify_df['Liveness'], errors='coerce')
spotify_df['Artist Followers'] = pd.to_numeric(spotify_df['Artist Followers'], errors='coerce')

# %%
spotify_df['Song Name'][0:5]
# Out:
# 0                              Beggin'
# 1            STAY (with Justin Bieber)
# 2                             good 4 u
# 3                           Bad Habits
# 4    INDUSTRY BABY (feat. Jack Harlow)
# Name: Song Name, dtype: object

# %%
spotify_df[['Song Name','Artist']][0:5]
# Out:
#                            Song Name          Artist
# 0                            Beggin'        Måneskin
# 1          STAY (with Justin Bieber)   The Kid LAROI
# 2                           good 4 u  Olivia Rodrigo
# 3                         Bad Habits      Ed Sheeran
# 4  INDUSTRY BABY (feat. Jack Harlow)       Lil Nas X

# %%
spotify_df.iloc[50:100,1:7]
# Out:
#     Highest Charting Position  Number of Times Charted  \
# 50                         19                        4
# 51                         52                        4
# 52                         19                        3
# 53                         40                       14
# 54                         52                        9
# 55                         56                       13
# 56                         57                        5
# 57                         31                       12
# 58                         34                       21
# 59                         31                       15
# 60                         46                        7
# 61                         26                       26
# 62                          9                       10
# 63                          2                       34
# 64                          8                       24
# 65                          2                       83
# ...

# %%
pd.crosstab(spotify_df['Popularity'], spotify_df['Genre'])
# Out:
# Genre       ['a cappella']  ['acoustic pop', 'neo mellow', 'pop', 'pop rock']  \
# Popularity
# 0.0                      0                                                  0
# 1.0                      0                                                  0
# 2.0                      0                                                  0
# 3.0                      0                                                  0
# 15.0                     0                                                  0
# ...                    ...                                                ...
# 96.0                     0                                                  0
# 97.0                     0                                                  0
# 98.0                     0                                                  0
# 99.0                     0                                                  0
# 100.0                    0                                                  0
#
# ...

# %%
spotify_df['Famous']=spotify_df['Artist Followers'] + spotify_df['Streams']
spotify_df[['Artist Followers', 'Streams', 'Famous']][0:5]
# Out:
#    Artist Followers  Streams  Famous
# 0         3377762.0      NaN     NaN
# 1         2230022.0      NaN     NaN
# 2         6266514.0      NaN     NaN
# 3        83293380.0      NaN     NaN
# 4         5473565.0      NaN     NaN

# %%
spotify_df[['Artist Followers', 'Streams', 'Famous']].sort_values('Famous',ascending=False)[0:5]
# Out:
#    Artist Followers  Streams  Famous
# 0         3377762.0      NaN     NaN
# 1         2230022.0      NaN     NaN
# 2         6266514.0      NaN     NaN
# 3        83293380.0      NaN     NaN
# 4         5473565.0      NaN     NaN

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
plt.bar(spotify_df['Genre'], spotify_df['Popularity'])
# Out:
# <BarContainer object of 1556 artists>

# %%
plt.bar(spotify_df['Artist'], spotify_df['Artist Followers'])
# Out:
# <BarContainer object of 1556 artists>

# %%
sn.barplot(spotify_df['Genre'],spotify_df['Number of Times Charted'])

# %%
plt.hist(spotify_df['Number of Times Charted']);

# %%
plt.hist(spotify_df['Number of Times Charted'], bins=20);

# %%
sn.distplot(spotify_df['Number of Times Charted']);

# %%
sn.distplot(spotify_df['Highest Charting Position']);

# %%
box = sn.boxplot(spotify_df['Number of Times Charted']);

# %%
sn.boxplot(x = 'Genre', y = 'Number of Times Charted', data = spotify_df);

# %%
influential_characterstics = ['Danceability', 'Energy', 'Loudness', 'Liveness']

# %%
spotify_df[influential_characterstics].corr()
# Out:
#               Danceability    Energy  Loudness  Liveness
# Danceability      1.000000  0.142130  0.234928 -0.114518
# Energy            0.142130  1.000000  0.732616  0.124693
# Loudness          0.234928  0.732616  1.000000  0.043141
# Liveness         -0.114518  0.124693  0.043141  1.000000

# %%
sn.heatmap(spotify_df[influential_characterstics].corr(), annot=True);
